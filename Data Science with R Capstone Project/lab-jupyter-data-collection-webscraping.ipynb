# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M1_R_Basics/images/IDSNlogo.png" width="200" align="center">
# </a>

# %% [markdown]
# <h1>Web scrape a Global Bike-Sharing Systems Wiki Page</h1>
#
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Lab Overview:
#
# Before getting your hands dirty on the actual data analysis tasks, you first need to obtain some background and context information about well-known bike sharing systems worldwide, such as their location, launch date, rental bike size, and so on.
#
# You can get such information from this Wiki page:
#
# [https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems](https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01)
#
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_1/images/l2-list-bike-sharing-systems.png" width="600" align="center">
# </a>

# %% [markdown]
# First import necessary libraries for the webscraping task.

# %% [markdown]
# In this lab, you need to use the `rvest` library to obtain the bike sharing systems table from the above web page, convert the table into a data frame, and write the data frame to a csv file for future data wrangling and analysis tasks.

# %%
# Check if need to install rvest` library
import numpy as np
import pandas as pd

# %% [markdown]
# # TASK: Extract bike sharing systems HTML table from a Wiki page and convert it into a data frame

# %% [markdown]
# _TODO:_ Get the root HTML node

# %%
url = "https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems"
# Get the root HTML node by calling the `read_html()` method with URL

df = pd.read_html(url)

# %%
df
# Out:
# [    0                                                  1
#  0 NaN  It has been suggested that this article be spl...,
#      0                                                  1
#  0 NaN  This article may have too many links to other ...,
#             Country                              City                 Name  \
#  0          Albania                         Tirana[5]             Ecovolis
#  1        Argentina                        Mendoza[6]            Metrobici
#  2        Argentina             San Lorenzo, Santa Fe             Biciudad
#  3        Argentina                Buenos Aires[7][8]              Ecobici
#  4        Argentina                           Rosario  Mi Bici Tu Bici[11]
#  ..             ...                               ...                  ...
#  479  United States     Santa Monica, California[315]    Breeze Bike Share
#  480  United States            Savannah, Georgia[316]             CAT Bike
#  481  United States          Seattle, Washington[317]   Pronto Cycle Share
#  482  United States  Spartanburg, South Carolina[318]  Spartanburg B-Cycle
#  483  United States                          St. Paul  Yellow Bike Project
#
#                                    System                        Operator  \
#  0                                    NaN                             NaN
#  1                                    NaN                             NaN
#  2                               Biciudad                             NaN
#  3                      Serttel Brasil[9]  Bike In Baires Consortium.[10]
#  4                                    NaN                             NaN
#  ..                                   ...                             ...
#  479  3 Gen. CycleHop and Social Bicycles                             NaN
#  480                       3 Gen. B-Cycle                             NaN
#  481                                   8D                        Motivate
#  482                       3 Gen. B-Cycle                             NaN
#  483                   1 Gen. w/ BikeCard     volunteers and city council
#
#               Launched   Discontinued Stations Bicycles Daily ridership
#  0          March 2011            NaN        8      200             NaN
#  1                2014            NaN        2       40             NaN
#  2    27 November 2016            NaN        8       80             NaN
#  3                2010            NaN      400     4000           21917
#  4     2 December 2015            NaN       47      480             NaN
#  ..                ...            ...      ...      ...             ...
#  479    13 August 2015            NaN       80      500             NaN
#  480   24 January 2014            NaN        2       16             NaN
#  481   13 October 2014  31 March 2017       50      500             NaN
#  482              2011            NaN        5       40             NaN
#  483              1997            NaN      NaN      NaN             NaN
#
#  [484 rows x 10 columns],
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteBicycle-sharing systems  \
#  0                     List of bicycle-sharing systems
#  1                                                Asia
#  2                                           East Asia
#  3                                          South Asia
#  4                                           West Asia
#  5                                        Central Asia
#  6                                              Europe
#  7                                       North America
#  8                                              Canada
#  9                                              Mexico
#  10                                      United States
#  11                                            Oceania
#  12                                      South America
#  13                                          Companies
#  14                                            Defunct
#
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteBicycle-sharing systems.1
#  0                     List of bicycle-sharing systems
#  1   East Asia Anywheel (Singapore) CityBike (Kaohs...
#  2   Anywheel (Singapore) CityBike (Kaohsiung, Taiw...
#  3   JoBike (Bangladesh) Ola Pedal (India) Tiruchir...
#  4   Antbis (Antalya) Bisim (İzmir) Cyacle Bikeshar...
#  5                    Astana Bike (Astana, Kazakhstan)
#  6   Aarhus City Bikes Belfast Bikes BicikeLJ (Ljub...
#  7   Canada Bike Share Toronto BIXI Montréal VeloGo...
#  8   Bike Share Toronto BIXI Montréal VeloGo (Ottaw...
#  9         EcoBici (Mexico City) Mi Bici (Guadalajara)
#  10  ArborBike (Ann Arbor) Arcata Bike Library (Arc...
#  11  Airbike CityCycle Melbourne Bike Share Nextbik...
#  12   Bike Rio (Rio de Janeiro) EcoBici (Buenos Aires)
#  13  8D Technologies B-cycle PBSC Urban Solutions J...
#  14  Baltimore Bike Share Bluegogo BIP! Perpignan C...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ,
#                0                                                  1
#  0     East Asia  Anywheel (Singapore) CityBike (Kaohsiung, Taiw...
#  1    South Asia  JoBike (Bangladesh) Ola Pedal (India) Tiruchir...
#  2     West Asia  Antbis (Antalya) Bisim (İzmir) Cyacle Bikeshar...
#  3  Central Asia                   Astana Bike (Astana, Kazakhstan),
#                 0                                                  1
#  0         Canada  Bike Share Toronto BIXI Montréal VeloGo (Ottaw...
#  1         Mexico        EcoBici (Mexico City) Mi Bici (Guadalajara)
#  2  United States  ArborBike (Ann Arbor) Arcata Bike Library (Arc...]

# %% [markdown]
# Note that this HTML page at least contains three child `<table>` nodes under the root HTML node. So, you will need to use `html_nodes(root_node, "table")` function to get all its child `<table>` nodes:
#
# ```
# <html>
#   <table>(table1)</table>
#   <table>(table2)</table>
#   <table>(table3)</table>
#   ...
# </html>
# ```

# %% [markdown]
# table_nodes <- html_nodes(root_node, "table")

# %% [markdown]
# You can use a `for` loop to print each table, and then you will see that the actual the bike sharing table is the second element `table_nodes[[2]]`.

# %% [markdown]
# Next, you need to convert this HTML table into a data frame using the `html_table()` function. You may choose to include `fill = TRUE` argument to fill any empty table rows/columns.

# %%
# Convert the bike-sharing system table into a dataframe
bikedf = df[2]
bikedf
# Out:
#            Country                              City                 Name  \
# 0          Albania                         Tirana[5]             Ecovolis
# 1        Argentina                        Mendoza[6]            Metrobici
# 2        Argentina             San Lorenzo, Santa Fe             Biciudad
# 3        Argentina                Buenos Aires[7][8]              Ecobici
# 4        Argentina                           Rosario  Mi Bici Tu Bici[11]
# ..             ...                               ...                  ...
# 479  United States     Santa Monica, California[315]    Breeze Bike Share
# 480  United States            Savannah, Georgia[316]             CAT Bike
# 481  United States          Seattle, Washington[317]   Pronto Cycle Share
# 482  United States  Spartanburg, South Carolina[318]  Spartanburg B-Cycle
# 483  United States                          St. Paul  Yellow Bike Project
#
#                                   System                        Operator  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                               Biciudad                             NaN
# 3                      Serttel Brasil[9]  Bike In Baires Consortium.[10]
# 4                                    NaN                             NaN
# ..                                   ...                             ...
# 479  3 Gen. CycleHop and Social Bicycles                             NaN
# 480                       3 Gen. B-Cycle                             NaN
# 481                                   8D                        Motivate
# 482                       3 Gen. B-Cycle                             NaN
# 483                   1 Gen. w/ BikeCard     volunteers and city council
#
#              Launched   Discontinued Stations Bicycles Daily ridership
# 0          March 2011            NaN        8      200             NaN
# 1                2014            NaN        2       40             NaN
# 2    27 November 2016            NaN        8       80             NaN
# 3                2010            NaN      400     4000           21917
# 4     2 December 2015            NaN       47      480             NaN
# ..                ...            ...      ...      ...             ...
# 479    13 August 2015            NaN       80      500             NaN
# 480   24 January 2014            NaN        2       16             NaN
# 481   13 October 2014  31 March 2017       50      500             NaN
# 482              2011            NaN        5       40             NaN
# 483              1997            NaN      NaN      NaN             NaN
#
# [484 rows x 10 columns]

# %% [markdown]
# Summarize the bike sharing system data frame

# %%
# Summarize the dataframe

bikedf.describe(include='all')
# Out:
#         Country    City      Name           System  Operator Launched  \
# count       484     484       442              341        82      453
# unique       57     444       325               92        43      248
# top     Germany  Berlin  nextbike  3 Gen. nextbike  JCDecaux     2010
# freq         63       9        24               61        16       30
#
#        Discontinued  Stations Bicycles Daily ridership
# count            28       408      408              23
# unique           24       168      189              23
# top            2016  dockless      500         675[97]
# freq              3        21       18               1

# %% [markdown]
# Export the data frame as a csv file called `raw_bike_sharing_systems.csv`

# %%
# Export the dataframe into a csv file
bikedf.to_csv('raw_bike_sharing_systems.csv', index=False)

# %% [markdown]
# For more details about webscraping with `rvest`, please refer to the previous webscraping notebook here:
#
# [Webscraping in R](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M4_Working_With_Data/lab3_jupyter_webscraping.ipynb)

# %% [markdown]
# ## Authors
#
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01" target="_blank">Yan Luo</a>

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-04-05        | 0.1     | Yan        | Initial version created |
# |                   |         |            |                         |
# |                   |         |            |                         |
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
