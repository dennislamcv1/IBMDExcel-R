# %% [markdown]
# For detailed info - https://medium.com/@joseph.magiya/weather-data-and-forecasts-from-open-weather-api-1636691d5ba

# %%
import requests
import pandas as pd

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Current Weather

# %% [markdown]
#  ### Using Coordinates

# %% [markdown]
# Current Weather Format (Coordinates) - api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={your api key}

# %%
lat = -1.2999792
long = 36.7728897
lat_long = "lat=" + str(lat)+ "&lon=" + str(long)

# %%
coord_API_endpoint = "http://api.openweathermap.org/data/2.5/weather?"
lat_long = "lat=" + str(lat)+ "&lon=" + str(long)
join_key = "&appid=" + "277a72f5a19ff756ca573d7eaf5e56d9"
units = "&units=metric"

# %%
current_coord_weather_url = coord_API_endpoint + lat_long + join_key + units

# %%
print(current_coord_weather_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?lat=-1.2999792&lon=36.7728897&appid=277a72f5a19ff756ca573d7eaf5e56d9&units=metric

# %% [markdown]
# ### Using City Name

# %% [markdown]
# Current Weather Format (City) - api.openweathermap.org/data/2.5/weather?q={city name},{state},{country code}&appid={your api key}

# %%
City_API_endpoint = "http://api.openweathermap.org/data/2.5/weather?q="
City = "Nairobi"
Country = ",KE,"
join_key = "&appid=" + "277a72f5a19ff756ca573d7eaf5e56d9"
units = "&units=metric"

# %%
current_city_weather = City_API_endpoint + City + Country + join_key + units

# %%
print(current_city_weather)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=Nairobi,KE,&appid=277a72f5a19ff756ca573d7eaf5e56d9&units=metric

# %% [markdown]
# # Reading the Data

# %%
json_data = requests.get(current_coord_weather_url).json()

# %%
print(json_data)
# Out:
# {'coord': {'lon': 36.7729, 'lat': -1.3}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 17.2, 'feels_like': 16.86, 'temp_min': 16.99, 'temp_max': 19.91, 'pressure': 1022, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 5.14, 'deg': 130}, 'clouds': {'all': 75}, 'dt': 1622534380, 'sys': {'type': 1, 'id': 2558, 'country': 'KE', 'sunrise': 1622518166, 'sunset': 1622561543}, 'timezone': 10800, 'id': 184745, 'name': 'Nairobi', 'cod': 200}

# %% [markdown]
# # Putting The Data into a DataFrame

# %%
df_all_current_weather = pd.DataFrame()
prediction_num = 0

# %%
# Create empty lists to store the JSON Data
current_weather_id = []
current_time = []
own_city_id = []
city = []
latitude = []
longitude = []
country = []
timezone = []
sunrise = []
sunset = []
temperature = []
temperature_feel = []
temperature_min = []
temperature_max = []
pressure = []
humidity = []
main = []
main_description = []
clouds = []
wind_speed = []
wind_degree = []
visibility = []

# %%
# Add JSON Data to the lists
prediction_num +=1
current_weather_id.append(prediction_num + 1)
current_time.append(pd.Timestamp.now())
own_city_id.append(json_data['id'])
city.append(json_data['name'])
latitude.append(json_data['coord']['lat'])
longitude.append(json_data['coord']['lon'])
country.append(json_data['sys']['country'])
if json_data['timezone'] >0 :
    timezone.append(("+" + str((json_data['timezone'])/3600)))
else:
    timezone.append(((json_data['timezone'])/3600))
sunrise.append(json_data['sys']['sunrise'])
sunset.append(json_data['sys']['sunset'])
temperature.append(json_data['main']['temp'])
temperature_feel.append(json_data['main']['feels_like'])
temperature_min.append(json_data['main']['temp_min'])
temperature_max.append(json_data['main']['temp_max'])
pressure.append(json_data['main']['pressure'])
humidity.append(json_data['main']['humidity'])
main.append(json_data['weather'][0]['main'])
main_description.append(json_data['weather'][0]['description'])
clouds.append(json_data['clouds']['all'])
wind_speed.append(json_data['wind']['speed'])
wind_degree.append(json_data['wind']['deg'])
visibility.append(json_data['visibility'])

# %%
# Write Lists to DataFrame
df_all_current_weather['current_weather_id'] = current_weather_id
df_all_current_weather['current_time'] = current_time
df_all_current_weather['own_city_id'] = own_city_id
df_all_current_weather['city'] = city
df_all_current_weather['latitude'] = latitude
df_all_current_weather['longitude'] = longitude
df_all_current_weather['country'] = country
df_all_current_weather['timezone'] = timezone
df_all_current_weather['sunrise'] = sunrise
df_all_current_weather['sunset'] = sunset
df_all_current_weather['temperature'] = temperature
df_all_current_weather['temperature_feel'] = temperature_feel
df_all_current_weather['temperature_min'] = temperature_min
df_all_current_weather['temperature_max'] = temperature_max
df_all_current_weather['pressure'] = pressure
df_all_current_weather['humidity'] = humidity
df_all_current_weather['main'] = main
df_all_current_weather['main_description'] = main_description
df_all_current_weather['clouds'] = clouds
df_all_current_weather['wind_speed'] = wind_speed
df_all_current_weather['wind_degree'] = wind_degree
df_all_current_weather['visibility'] = visibility

# %%
df_all_current_weather.head(5)
# Out:
#    current_weather_id               current_time  own_city_id     city  \
# 0                   2 2021-06-01 15:59:39.067307       184745  Nairobi
#
#    latitude  longitude country timezone     sunrise      sunset  temperature  \
# 0      -1.3    36.7729      KE     +3.0  1622518166  1622561543         17.2
#
#    temperature_feel  temperature_min  temperature_max  pressure  humidity  \
# 0             16.86            16.99            19.91      1022        72
#
#      main main_description  clouds  wind_speed  wind_degree  visibility
# 0  Clouds    broken clouds      75        5.14          130       10000

# %% [markdown]
# # Forecast

# %% [markdown]
# ### Forecast Data Using Coordinates

# %% [markdown]
# Format - api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={your api key}

# %%
lat = -1.2999792
long = 36.7728897
lat_long = "lat=" + str(lat)+ "&lon=" + str(long)

# %%
coord_API_endpoint = "http://api.openweathermap.org/data/2.5/forecast?"
lat_long = "lat=" + str(lat)+ "&lon=" + str(long)
join_key = "&appid=" + "277a72f5a19ff756ca573d7eaf5e56d9"
units = "&units=metric"

# %%
forecast_coord_weather_url = coord_API_endpoint + lat_long + join_key + units

# %%
print (forecast_coord_weather_url)
# Out:
# http://api.openweathermap.org/data/2.5/forecast?lat=-1.2999792&lon=36.7728897&appid=277a72f5a19ff756ca573d7eaf5e56d9&units=metric

# %% [markdown]
# ### By City Name

# %% [markdown]
# Format - api.openweathermap.org/data/2.5/forecast?q={city name},{state},{country code}&appid={your api key}

# %%
City_API_endpoint = "http://api.openweathermap.org/data/2.5/forecast?q="
City = "Nairobi"
Country = ",KE,"
join_key = "&appid=" + "277a72f5a19ff756ca573d7eaf5e56d9"
units = "&units=metric"

# %%
city_forecast = City_API_endpoint + City + Country + join_key + units

# %%
print(city_forecast)
# Out:
# http://api.openweathermap.org/data/2.5/forecast?q=Nairobi,KE,&appid=277a72f5a19ff756ca573d7eaf5e56d9&units=metric

# %% [markdown]
# # Requesting for the Forecast Weather Data

# %%
forecast_json_data = requests.get(city_forecast).json()

# %%
print(forecast_json_data)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1622538000, 'main': {'temp': 17.81, 'feels_like': 17.53, 'temp_min': 17.81, 'temp_max': 21.99, 'pressure': 1022, 'sea_level': 1022, 'grnd_level': 839, 'humidity': 72, 'temp_kf': -4.18}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 75}, 'wind': {'speed': 3.04, 'deg': 114, 'gust': 4.13}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2021-06-01 09:00:00'}, {'dt': 1622548800, 'main': {'temp': 19.82, 'feels_like': 19.48, 'temp_min': 19.82, 'temp_max': 23.84, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 837, 'humidity': 62, 'temp_kf': -4.02}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 73}, 'wind': {'speed': 4.02, 'deg': 111, 'gust': 4.87}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2021-06-01 12:00:00'}, {'dt': 1622559600, 'main': {'temp': 19.44, 'feels_like': 19.01, 'temp_min': 19.44, 'temp_max': 20.26, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 836, 'humidity': 60, 'temp_kf': -0.82}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 92}, 'wind': {'speed': 3.91, 'deg': 104, 'gust': 7.1}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2021-06-01 15:00:00'}, {'dt': 1622570400, 'main': {'temp': 17.99, 'feels_like': 17.31, 'temp_min': 17.99, 'temp_max': 17.99, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 838, 'humidity': 56, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.79, 'deg': 90, 'gust': 8.77}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2021-06-01 18:00:00'}, {'dt': 1622581200, 'main': {'temp': 14.86, 'feels_like': 14.75, 'temp_min': 14.86, 'temp_max': 14.86, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 837, 'humidity': 90, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 2.88, 'deg': 76, 'gust': 5.3}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2021-06-01 21:00:00'}, {'dt': 1622592000, 'main': {'temp': 15.06, 'feels_like': 14.84, 'temp_min': 15.06, 'temp_max': 15.06, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 836, 'humidity': 85, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 97}, 'wind': {'speed': 2.92, 'deg': 66, 'gust': 4.37}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2021-06-02 00:00:00'}, {'dt': 1622602800, 'main': {'temp': 14.23, 'feels_like': 14.06, 'temp_min': 14.23, 'temp_max': 14.23, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 837, 'humidity': 90, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 98}, 'wind': {'speed': 1.96, 'deg': 73, 'gust': 3.83}, 'visibility': 10000, 'pop': 0.03, 'sys': {'pod': 'n'}, 'dt_txt': '2021-06-02 03:00:00'}, {'dt': 1622613600, 'main': {'temp': 16.34, 'feels_like': 16.12, 'temp_min': 16.34, 'temp_max': 16.34, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 840, 'humidity': 80, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 98}, 'wind': {'speed': 1.87, 'deg': 116, 'gust': 2.7}, 'visibility': 10000, 'pop': 0.2, 'rain': {'3h': 0.12}, 'sys': {'pod': 'd'}, 'dt_txt': '2021-06-02 06:00:00'}, {'dt': 1622624400, 'main': {'temp': 21.48, 'feels_like': 21.09, 'temp_min': 21.48, 'temp_max': 21.48, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 840, 'humidity': 54, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 87}, 'wind': {'speed': 2.72, 'deg': 111, 'gust': 2.85}, 'visibility': 10000, 'pop': 0, 'sys' ...

# %%
# forecast_main = forecast_json_data['weather'][0]['main']
# forecast_main_description = forecast_json_data['weather'][0]['description']
# forecast_temperature = forecast_json_data['main']['temp']
# forecast_temperature_feel = forecast_json_data['main']['feels_like']
# forecast_temperature_min = forecast_json_data['main']['temp_min']
# forecast_temperature_max = forecast_json_data['main']['temp_max']
# forecast_pressure = forecast_json_data['main']['pressure']
# forecast_humidity = forecast_json_data['main']['humidity']
# forecast_visibility = forecast_json_data['visibility']
# forecast_wind_speed = forecast_json_data['wind']['speed']
# forecast_wind_degree = forecast_json_data['wind']['deg']

# %%
forecast_main = forecast_json_data['list'][0]['main']

# %%
num_forecasts = len(forecast_json_data['list'])
num_forecasts
# Out:
# 40

# %%
forecast_json_data['city']
# Out:
# {'id': 184745,
#  'name': 'Nairobi',
#  'coord': {'lat': -1.2833, 'lon': 36.8167},
#  'country': 'KE',
#  'population': 2750547,
#  'timezone': 10800,
#  'sunrise': 1622518154,
#  'sunset': 1622561535}

# %% [markdown]
# # Putting The Current Weather Data into a Pandas Data Frame

# %%
df_predictions = pd.DataFrame()

# %%
# Creating empty lists
prediction_num = 0
list_prediction_num = []
date_time_prediction = []
owm_city_id = []
city_name = []
latitude = []
longitude = []
country_name = []
population = []
timezone = [] # Shift in seconds from UTC
sunrise = []
sunset = []
# Main
temp_prediction = []
temp_feels_like_prediction = []
temp_min_prediction = []
temp_max_prediction = []
pressure_prediction = []
sea_level_prediction = []
grnd_level_prediction = []
humidity_prediction = []
temp_kf_prediction = []
# Weather
main_weather_prediction = []
main_weather_description_prediction = []
# Clouds
clouds_prediction = []
# Wind
wind_speed_prediction = []
wind_degree_prediction = []

# %%
# Loop Through the JSON
for num_forecasts in forecast_json_data['list']:
    df_predictions['prediction_num'] = prediction_num
    list_prediction_num.append(prediction_num)
    date_time_prediction.append(forecast_json_data['list'][prediction_num]['dt_txt'])
    
    owm_city_id.append(forecast_json_data['city']['id'])
    city_name.append(forecast_json_data['city']['name'])
    latitude.append(forecast_json_data['city']['coord']['lat'])
    longitude.append(forecast_json_data['city']['coord']['lon'])
    country_name.append(forecast_json_data['city']['country'])
    population.append(forecast_json_data['city']['population'])
    
    if forecast_json_data['city']['timezone'] >0 :
        timezone.append("+" + str((forecast_json_data['city']['timezone'])/3600))
    else:
        timezone.append((forecast_json_data['city']['timezone'])/3600)
        
    sunrise.append(forecast_json_data['city']['sunrise'])
    sunset.append(forecast_json_data['city']['sunset'])
    
    # Main
    temp_prediction.append(forecast_json_data['list'][prediction_num]['main']['temp'])
    temp_feels_like_prediction.append(forecast_json_data['list'][prediction_num]['main']['feels_like'])
    temp_min_prediction.append(forecast_json_data['list'][prediction_num]['main']['temp_min'])
    temp_max_prediction.append(forecast_json_data['list'][prediction_num]['main']['temp_max'])
    pressure_prediction.append(forecast_json_data['list'][prediction_num]['main']['pressure'])
    sea_level_prediction.append(forecast_json_data['list'][prediction_num]['main']['sea_level'])
    grnd_level_prediction.append(forecast_json_data['list'][prediction_num]['main']['grnd_level'])
    humidity_prediction.append(forecast_json_data['list'][prediction_num]['main']['humidity'])
    temp_kf_prediction.append(forecast_json_data['list'][prediction_num]['main']['temp_kf'])
    # Weather
    main_weather_prediction.append(forecast_json_data['list'][prediction_num]['weather'][0]['main'])
    main_weather_description_prediction.append(forecast_json_data['list'][prediction_num]['weather'][0]['description'])
    # Clouds
    clouds_prediction.append(forecast_json_data['list'][prediction_num]['clouds']['all'])
    # Wind
    wind_speed_prediction.append(forecast_json_data['list'][prediction_num]['wind']['speed'])
    wind_degree_prediction.append(forecast_json_data['list'][prediction_num]['wind']['deg'])
    
    prediction_num += 1

# %%
# Put data into a dataframe
df_predictions['prediction_num'] = list_prediction_num
df_predictions['date_time_prediction'] = date_time_prediction
df_predictions['owm_city_id'] = owm_city_id
df_predictions['city_name'] = city_name
df_predictions['latitude'] = latitude
df_predictions['longitude'] = longitude
df_predictions['country_name'] = country_name
df_predictions['population'] = population
df_predictions['timezone'] = timezone
df_predictions['sunrise'] = sunrise
df_predictions['sunset'] = sunset

    # Main
df_predictions['temp_prediction'] = temp_prediction
df_predictions['temp_feels_like_prediction'] = temp_feels_like_prediction
df_predictions['temp_min_prediction'] = temp_min_prediction
df_predictions['temp_max_prediction'] = temp_max_prediction
df_predictions['pressure_prediction'] = pressure_prediction
df_predictions['sea_level_prediction'] = sea_level_prediction
df_predictions['grnd_level_prediction'] = grnd_level_prediction
df_predictions['humidity_prediction'] = humidity_prediction
df_predictions['temp_kf_prediction'] = temp_kf_prediction
    # Weather
df_predictions['main_weather_prediction'] = main_weather_prediction
df_predictions['main_weather_description_prediction'] = main_weather_description_prediction
    # Clouds
df_predictions['clouds_prediction'] = clouds_prediction
    # Wind
df_predictions['wind_speed_prediction'] = wind_speed_prediction
df_predictions['wind_degree_prediction'] = wind_degree_prediction

# %%
df_predictions.head()
# Out:
#    prediction_num date_time_prediction  owm_city_id city_name  latitude  \
# 0               0  2021-06-01 09:00:00       184745   Nairobi   -1.2833
# 1               1  2021-06-01 12:00:00       184745   Nairobi   -1.2833
# 2               2  2021-06-01 15:00:00       184745   Nairobi   -1.2833
# 3               3  2021-06-01 18:00:00       184745   Nairobi   -1.2833
# 4               4  2021-06-01 21:00:00       184745   Nairobi   -1.2833
#
#    longitude country_name  population timezone     sunrise      sunset  \
# 0    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 1    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 2    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 3    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 4    36.8167           KE     2750547     +3.0  1622518154  1622561535
#
#    temp_prediction  temp_feels_like_prediction  temp_min_prediction  \
# 0            17.81                       17.53                17.81
# 1            19.82                       19.48                19.82
# 2            19.44                       19.01                19.44
# 3            17.99                       17.31                17.99
# 4            14.86                       14.75                14.86
#
#    temp_max_prediction  pressure_prediction  sea_level_prediction  \
# 0                21.99                 1022                  1022
# 1                23.84                 1018                  1018
# 2                20.26                 1016                  1016
# 3                17.99                 1016                  1016
# 4                14.86                 1017                  1017
#
#    grnd_level_prediction  humidity_prediction  temp_kf_prediction  \
# 0                    839                   72               -4.18
# 1                    837                   62               -4.02
# 2                    836                   60               -0.82
# 3                    838                   56                0.00
# 4                    837                   90                0.00
#
#   main_weather_prediction main_weather_description_prediction  \
# 0                  Clouds                       broken clouds
# 1                  Clouds                       broken clouds
# 2                  Clouds                     overcast clouds
# 3                  Clouds                     overcast clouds
# 4                  Clouds                     overcast clouds
#
#    clouds_prediction  wind_speed_prediction  wind_degree_prediction
# 0                 75                   3.04                     114
# 1                 73                   4.02                     111
# 2                 92                   3.91                     104
# 3                100                   3.79                      90
# 4                100                   2.88                      76

# %%
df_predictions
# Out:
#     prediction_num date_time_prediction  owm_city_id city_name  latitude  \
# 0                0  2021-06-01 09:00:00       184745   Nairobi   -1.2833
# 1                1  2021-06-01 12:00:00       184745   Nairobi   -1.2833
# 2                2  2021-06-01 15:00:00       184745   Nairobi   -1.2833
# 3                3  2021-06-01 18:00:00       184745   Nairobi   -1.2833
# 4                4  2021-06-01 21:00:00       184745   Nairobi   -1.2833
# 5                5  2021-06-02 00:00:00       184745   Nairobi   -1.2833
# 6                6  2021-06-02 03:00:00       184745   Nairobi   -1.2833
# 7                7  2021-06-02 06:00:00       184745   Nairobi   -1.2833
# 8                8  2021-06-02 09:00:00       184745   Nairobi   -1.2833
# 9                9  2021-06-02 12:00:00       184745   Nairobi   -1.2833
# 10              10  2021-06-02 15:00:00       184745   Nairobi   -1.2833
# 11              11  2021-06-02 18:00:00       184745   Nairobi   -1.2833
# 12              12  2021-06-02 21:00:00       184745   Nairobi   -1.2833
# 13              13  2021-06-03 00:00:00       184745   Nairobi   -1.2833
# 14              14  2021-06-03 03:00:00       184745   Nairobi   -1.2833
# 15              15  2021-06-03 06:00:00       184745   Nairobi   -1.2833
# 16              16  2021-06-03 09:00:00       184745   Nairobi   -1.2833
# 17              17  2021-06-03 12:00:00       184745   Nairobi   -1.2833
# 18              18  2021-06-03 15:00:00       184745   Nairobi   -1.2833
# 19              19  2021-06-03 18:00:00       184745   Nairobi   -1.2833
# 20              20  2021-06-03 21:00:00       184745   Nairobi   -1.2833
# 21              21  2021-06-04 00:00:00       184745   Nairobi   -1.2833
# 22              22  2021-06-04 03:00:00       184745   Nairobi   -1.2833
# 23              23  2021-06-04 06:00:00       184745   Nairobi   -1.2833
# 24              24  2021-06-04 09:00:00       184745   Nairobi   -1.2833
# 25              25  2021-06-04 12:00:00       184745   Nairobi   -1.2833
# 26              26  2021-06-04 15:00:00       184745   Nairobi   -1.2833
# 27              27  2021-06-04 18:00:00       184745   Nairobi   -1.2833
# 28              28  2021-06-04 21:00:00       184745   Nairobi   -1.2833
# 29              29  2021-06-05 00:00:00       184745   Nairobi   -1.2833
# 30              30  2021-06-05 03:00:00       184745   Nairobi   -1.2833
# 31              31  2021-06-05 06:00:00       184745   Nairobi   -1.2833
# 32              32  2021-06-05 09:00:00       184745   Nairobi   -1.2833
# 33              33  2021-06-05 12:00:00       184745   Nairobi   -1.2833
# 34              34  2021-06-05 15:00:00       184745   Nairobi   -1.2833
# 35              35  2021-06-05 18:00:00       184745   Nairobi   -1.2833
# 36              36  2021-06-05 21:00:00       184745   Nairobi   -1.2833
# 37              37  2021-06-06 00:00:00       184745   Nairobi   -1.2833
# 38              38  2021-06-06 03:00:00       184745   Nairobi   -1.2833
# 39              39  2021-06-06 06:00:00       184745   Nairobi   -1.2833
#
#     longitude country_name  population timezone     sunrise      sunset  \
# 0     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 1     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 2     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 3     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 4     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 5     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 6     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 7     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 8     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 9     36.8167           KE     2750547     +3.0  1622518154  1622561535
# 10    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 11    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 12    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 13    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 14    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 15    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 16    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 17    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 18    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 19    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 20    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 21    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 22    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 23    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 24    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 25    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 26    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 27    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 28    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 29    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 30    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 31    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 32    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 33    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 34    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 35    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 36    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 37    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 38    36.8167           KE     2750547     +3.0  1622518154  1622561535
# 39    36.8167           KE     2750547     +3.0  1622518154  1622561535
#
#     temp_prediction  temp_feels_like_prediction  temp_min_prediction  \
# 0             17.81                       17.53                17.81
# 1             19.82                       19.48                19.82
# 2             19.44                       19.01                19.44
# 3             17.99                       17.31                17.99
# 4             14.86                       14.75                14.86
# 5             15.06                       14.84                15.06
# 6             14.23                       14.06                14.23
# 7             16.34                       16.12                16.34
# 8             21.48                       21.09                21.48
# 9             23.96                       23.53                23.96
# 10            19.91                       19.50                19.91
# 11            17.37                       16.65                17.37
# 12            15.20                       14.68                15.20
# 13            13.33                       12.91                13.33
# 14            12.52                       12.13                12.52
# 15            18.19                       17.79                18.19
# 16            23.24                       22.85                23.24
# 17            25.46                       25.11                25.46
# 18            21.31                       20.96                21.31
# 19            17.81                       17.68                17.81
# 20            16.31                       16.22                16.31
# 21            15.45                       15.45                15.45
# 22            15.62                       15.46                15.62
# 23            17.86                       17.61                17.86
# 24            22.86                       22.59                22.86
# 25            25.06                       24.74                25.06
# 26            20.00                       19.83                20.00
# 27            17.21                       17.18                17.21
# 28            16.37                       16.28                16.37
# 29            15.36                       15.25                15.36
# 30            13.51                       13.40                13.51
# 31            17.82                       17.54                17.82
# 32            22.73                       22.39                22.73
# 33            23.63                       23.30                23.63
# 34            20.06                       19.66                20.06
# 35            19.00                       18.52                19.00
# 36            16.29                       16.06                16.29
# 37            14.84                       14.76                14.84
# 38            15.29                       15.17                15.29
# 39            16.53                       16.35                16.53
#
#     temp_max_prediction  pressure_prediction  sea_level_prediction  \
# 0                 21.99                 1022                  1022
# 1                 23.84                 1018                  1018
# 2                 20.26                 1016                  1016
# 3                 17.99                 1016                  1016
# 4                 14.86                 1017                  1017
# 5                 15.06                 1016                  1016
# 6                 14.23                 1017                  1017
# 7                 16.34                 1019                  1019
# 8                 21.48                 1016                  1016
# 9                 23.96                 1012                  1012
# 10                19.91                 1014                  1014
# 11                17.37                 1017                  1017
# 12                15.20                 1017                  1017
# 13                13.33                 1017                  1017
# 14                12.52                 1018                  1018
# 15                18.19                 1019                  1019
# 16                23.24                 1016                  1016
# 17                25.46                 1012                  1012
# 18                21.31                 1014                  1014
# 19                17.81                 1017                  1017
# 20                16.31                 1018                  1018
# 21                15.45                 1017                  1017
# 22                15.62                 1018                  1018
# 23                17.86                 1019                  1019
# 24                22.86                 1016                  1016
# 25                25.06                 1012                  1012
# 26                20.00                 1015                  1015
# 27                17.21                 1018                  1018
# 28                16.37                 1018                  1018
# 29                15.36                 1017                  1017
# 30                13.51                 1019                  1019
# 31                17.82                 1019                  1019
# 32                22.73                 1016                  1016
# 33                23.63                 1013                  1013
# 34                20.06                 1015                  1015
# 35                19.00                 1017                  1017
# 36                16.29                 1018                  1018
# 37                14.84                 1017                  1017
# 38                15.29                 1018                  1018
# 39                16.53                 1020                  1020
#
#     grnd_level_prediction  humidity_prediction  temp_kf_prediction  \
# 0                     839                   72               -4.18
# 1                     837                   62               -4.02
# 2                     836                   60               -0.82
# 3                     838                   56                0.00
# 4                     837                   90                0.00
# 5                     836                   85                0.00
# 6                     837                   90                0.00
# 7                     840                   80                0.00
# 8                     840                   54                0.00
# 9                     838                   43                0.00
# 10                    837                   59                0.00
# 11                    838                   57                0.00
# 12                    837                   73                0.00
# 13                    836                   84                0.00
# 14                    836                   88                0.00
# 15                    840                   66                0.00
# 16                    840                   47                0.00
# 17                    838                   40                0.00
# 18                    838                   56                0.00
# 19                    839                   78                0.00
# 20                    838                   85                0.00
# 21                    837                   92                0.00
# 22                    838                   85                0.00
# 23                    840                   73                0.00
# 24                    840                   53                0.00
# 25                    838                   43                0.00
# 26                    838                   68                0.00
# 27                    839                   84                0.00
# 28                    838                   85                0.00
# 29                    837                   88                0.00
# 30                    838                   95                0.00
# 31                    840                   72                0.00
# 32                    841                   51                0.00
# 33                    838                   48                0.00
# 34                    838                   59                0.00
# 35                    839                   60                0.00
# 36                    839                   80                0.00
# 37                    837                   91                0.00
# 38                    838                   88                0.00
# 39                    841                   81                0.00
#
#    main_weather_prediction main_weather_description_prediction  \
# 0                   Clouds                       broken clouds
# 1                   Clouds                       broken clouds
# 2                   Clouds                     overcast clouds
# 3                   Clouds                     overcast clouds
# 4                   Clouds                     overcast clouds
# 5                   Clouds                     overcast clouds
# 6                   Clouds                     overcast clouds
# 7                     Rain                          light rain
# 8                   Clouds                     overcast clouds
# 9                   Clouds                       broken clouds
# 10                  Clouds                       broken clouds
# 11                  Clouds                       broken clouds
# 12                  Clouds                       broken clouds
# 13                  Clouds                       broken clouds
# 14                  Clouds                    scattered clouds
# 15                  Clouds                    scattered clouds
# 16                  Clouds                          few clouds
# 17                  Clouds                    scattered clouds
# 18                  Clouds                     overcast clouds
# 19                    Rain                          light rain
# 20                  Clouds                     overcast clouds
# 21                  Clouds                     overcast clouds
# 22                  Clouds                     overcast clouds
# 23                  Clouds                     overcast clouds
# 24                  Clouds                       broken clouds
# 25                    Rain                          light rain
# 26                    Rain                          light rain
# 27                    Rain                          light rain
# 28                    Rain                          light rain
# 29                  Clouds                     overcast clouds
# 30                  Clouds                    scattered clouds
# 31                  Clouds                    scattered clouds
# 32                  Clouds                          few clouds
# 33                    Rain                          light rain
# 34                  Clouds                     overcast clouds
# 35                  Clouds                     overcast clouds
# 36                  Clouds                       broken clouds
# 37                  Clouds                       broken clouds
# 38                  Clouds                     overcast clouds
# 39                    Rain                          light rain
#
#     clouds_prediction  wind_speed_prediction  wind_degree_prediction
# 0                  75                   3.04                     114
# 1                  73                   4.02                     111
# 2                  92                   3.91                     104
# 3                 100                   3.79                      90
# 4                 100                   2.88                      76
# 5                  97                   2.92                      66
# 6                  98                   1.96                      73
# 7                  98                   1.87                     116
# 8                  87                   2.72                     111
# 9                  64                   3.30                     120
# 10                 82                   2.40                     124
# 11                 80                   2.29                      73
# 12                 63                   2.24                      77
# 13                 65                   1.42                      59
# 14                 49                   1.03                      15
# 15                 33                   1.35                     133
# 16                 18                   2.88                     129
# 17                 39                   3.19                     128
# 18                 95                   2.32                      93
# 19                 92                   2.28                      58
# 20                 97                   3.08                      78
# 21                 98                   1.31                      93
# 22                100                   1.32                      59
# 23                100                   1.64                      79
# 24                 78                   2.44                     101
# 25                 54                   3.05                     121
# 26                 89                   3.15                     123
# 27                 88                   2.42                      84
# 28                 96                   3.63                      58
# 29                 93                   2.08                      46
# 30                 46                   1.60                      32
# 31                 42                   2.16                      59
# 32                 21                   3.43                      94
# 33                 51                   4.47                     136
# 34                100                   2.59                     111
# 35                100                   2.98                      86
# 36                 79                   1.96                      79
# 37                 81                   1.36                      57
# 38                 92                   1.80                      85
# 39                 96                   2.14                      68
